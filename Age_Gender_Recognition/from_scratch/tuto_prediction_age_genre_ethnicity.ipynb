# %% [markdown]
# # Tuto pour la prédicition multiclasse
#
# C'est quasiment tout pareil

# %%
#imports
import pandas as pd
import numpy as np
import os
import fnmatch
from random import shuffle
import cv2

os.chdir('utkcropped')

# %%
# Liste pour stocker les noms des images
liste_noms_images = []

for nom_fichier in os.listdir():
    if nom_fichier.endswith('.jpg') or nom_fichier.endswith('.jpeg') or nom_fichier.endswith('.png'):
        liste_noms_images.append(nom_fichier)

# %%
# Définition des listes pour stocker les données
liste_age = []
liste_genre = []
liste_ethnicite = []
liste_noms_images = []
liste_images_numpy = []

"""
for nom_fichier in os.listdir():
    print(nom_fichier)
    if nom_fichier.endswith('.jpg'):
        parties = nom_fichier.split('_')
        if len(parties) == 4 and parties[3].endswith('.jpg'):
            age = int(parties[0])
            genre = int(parties[1])
            ethnicite = int(parties[2])

            liste_age.append(age)
            liste_genre.append(genre)
            liste_ethnicite.append(ethnicite)
            liste_noms_images.append(nom_fichier)

            chemin_image = os.path.join(os.getcwd(), nom_fichier)
            image = cv2.imread(chemin_image)
            if image is not None:
                liste_images_numpy.append(image)
                """
                
#On charge directement 2000 images pour aller plus vite (tu peux modifier)            
# Compteur pour limiter à 2000 images
compteur_images = 0

# Parcourir les fichiers dans le répertoire
for nom_fichier in os.listdir():
    print(nom_fichier)
    if compteur_images >= 10000:
        break  # Sortir de la boucle si le compteur atteint 2000 images

    if nom_fichier.endswith('.jpg'):
        # Séparation du nom du fichier en parties
        parties = nom_fichier.split('_')
        if len(parties) == 4 and parties[3].endswith('.jpg'):
            # Extraction des informations
            age = int(parties[0])
            genre = int(parties[1])
            ethnicite = int(parties[2])

            # Ajout des informations aux listes correspondantes
            liste_age.append(age)
            liste_genre.append(genre)
            liste_ethnicite.append(ethnicite)
            liste_noms_images.append(nom_fichier)

            # Chargement de l'image en tableau numpy
            chemin_image = os.path.join(os.getcwd(), nom_fichier)
            image = cv2.imread(chemin_image)
            if image is not None:
                liste_images_numpy.append(image)
                compteur_images += 1  # Incrémenter le compteur d'images
                print(compteur_images)

# Afficher le nombre total d'images chargées
print("Nombre total d'images chargées:", len(liste_images_numpy))
# Out:
# 9_1_2_20161219204347420.jpg.chip.jpg
# 1
# 36_0_1_20170117163203851.jpg.chip.jpg
# 2
# 86_1_0_20170120225751953.jpg.chip.jpg
# 3
# 26_1_0_20170116171048641.jpg.chip.jpg
# 4
# 1_1_2_20161219154612988.jpg.chip.jpg
# 5
# 52_0_1_20170117161018159.jpg.chip.jpg
# 6
# 25_1_0_20170117134403373.jpg.chip.jpg
# 7
# 16_0_0_20170104003740977.jpg.chip.jpg
# 8
# 27_0_3_20170119210058457.jpg.chip.jpg
# 9
# 36_0_3_20170119180245724.jpg.chip.jpg
# 10
# 58_0_2_20170116193704928.jpg.chip.jpg
# 11
# 6_1_0_20170114024512634.jpg.chip.jpg
# 12
# 35_1_2_20170116185947151.jpg.chip.jpg
# 13
# 1_1_3_20161219230734016.jpg.chip.jpg
# 14
# 26_1_1_20170103181931657.jpg.chip.jpg
# 15
# 2_0_2_20161219141650121.jpg.chip.jpg
# 16
# 53_1_0_20170110143534851.jpg.chip.jpg
# 17
# 35_0_3_20170119201304861.jpg.chip.jpg
# 18
# 23_1_0_20170117142807780.jpg.chip.jpg
# 19
# 24_0_3_20170119152239904.jpg.chip.jpg
# 20
# 26_1_2_20170116182434267.jpg.chip.jpg
# 21
# 75_0_0_20170117204739711.jpg.chip.jpg
# 22
# ...

# %%
# Création du DataFrame
data = {
    'filename': liste_noms_images,
    'age': liste_age,
    'gender': liste_genre,
    'ethnicity': liste_ethnicite,
    'pixels': liste_images_numpy,
}

df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#                                 filename  age  gender  ethnicity  \
# 0   9_1_2_20161219204347420.jpg.chip.jpg    9       1          2
# 1  36_0_1_20170117163203851.jpg.chip.jpg   36       0          1
# 2  86_1_0_20170120225751953.jpg.chip.jpg   86       1          0
# 3  26_1_0_20170116171048641.jpg.chip.jpg   26       1          0
# 4   1_1_2_20161219154612988.jpg.chip.jpg    1       1          2
#
#                                               pixels
# 0  [[[74, 107, 93], [71, 104, 90], [68, 101, 87],...
# 1  [[[43, 228, 242], [42, 227, 241], [42, 225, 24...
# 2  [[[210, 230, 225], [208, 228, 223], [206, 226,...
# 3  [[[252, 238, 239], [252, 238, 239], [252, 238,...
# 4  [[[51, 63, 97], [49, 61, 95], [45, 57, 91], [4...

# %%
#On tej les vieux
df = df[df['age'] < 80].reset_index(drop=True)

#On normalise l'âge 
max_age = df['age'].max()
df['age'] = df['age']/max_age

# %% [markdown]
# ## Prédicition du genre, de l'âge et de l'ethnicité
#
# Ouais je sais tu t'en balec de l'ethnicité mais c'est aussi pour te montrer comment on fait pour plusieurs classes, et ça te permettra d'adapter aux deux prédicitions que tu veux ça peut faire un bon exo (genre je suis ton prof tsais)

# %%
X = np.array(df['pixels'].tolist())

y = df[['age', 'gender', 'ethnicity']].values

# %%
y
# Out:
# array([[0.11392405, 1.        , 2.        ],
#        [0.4556962 , 0.        , 1.        ],
#        [0.32911392, 1.        , 0.        ],
#        ...,
#        [0.05063291, 0.        , 0.        ],
#        [0.48101266, 1.        , 0.        ],
#        [0.60759494, 1.        , 0.        ]])

# %% [markdown]
# Tout pareil

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# Alors là ça va être un peu différent, la première partie du modèle est exactement la même, tout ce qui change est la sortie, ici on aura trois couches de sorties concaténées pour 3 prédicitions différentes, les deux premières c'est exactement ce qu'on a vu avant, et la dernière y a 5 neurones pour 5 classes et une fonction softmax (comme sigmoid mais normalisée)
#
# Autre différence, la syntaxe est un peu différente mais ça fonctionne de la même manière (pour te donner les deux types d'écriture en tensorflow)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Input


input_shape = (200,200,3)

input_model = Input(input_shape)

x = Conv2D(filters=32, kernel_size=(5, 5), padding='valid', input_shape=input_shape, activation='relu')(input_model)
x = MaxPooling2D(pool_size=(2, 2))(x)
# x = Dropout(rate=0.2)(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='valid', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=(3, 3), padding='valid', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
# x = Dropout(rate=0.2)(x)

x = Flatten()(x)

x = Dense(units=128, activation='relu')(x)
x = Dropout(rate=0.2)(x)
x = Dense(units=64, activation='relu')(x)

age = Dense(units=1, activation='sigmoid')(x)
gender = Dense(units=1, activation='sigmoid')(x)
ethnicity = Dense(units=5, activation='softmax')(x)

model = Model(inputs=input_model, outputs=tf.concat([age, gender, ethnicity], axis=-1))


model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 196, 196, 32) 2432        input_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 98, 98, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 96, 96, 64)   18496       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 48, 48, 64)   0           conv2d_7[0][0]
# ...

# %% [markdown]
# Avant de compiler, on définit une nouvelle fonction de perte générale qui correspond à la somme des fonctions de pertes des trois prédictions pondérées en fonction de ce qui nous semble le plus important. On pourrait mettre plus de poids sur l'age comme c'est le plus galere mais ca marche pas de fou la donc j'ai un peu fait empiriquement.

# %%
import tensorflow as tf


lambda_age = 1
lambda_gender = 1
lambda_ethnicity = 1

def loss_age(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true-y_pred), axis=-1)

def loss_gender(y_true, y_pred):
    return tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)

def loss_ethnicity(y_true, y_pred):
    return tf.keras.losses.SparseCategoricalCrossentropy()(y_true, y_pred)


def loss_function(y_true, y_pred):
    # return loss_age(y_true[:,0], y_pred[:,0]), loss_gender(y_true[:,1], y_pred[:,1]), loss_ethnicity(y_true[:,2], y_pred[:,2:]) 
    return lambda_age*loss_age(tf.cast(y_true[:,0], tf.float32), y_pred[:,0]) +  lambda_gender*loss_gender(y_true[:,1], y_pred[:,1]) + lambda_ethnicity*loss_ethnicity(y_true[:,2], y_pred[:,2:])

# %% [markdown]
# On définit également des métriques pour les trois différentes prédictions (différence pour la nouvelle, on utilise une categorical crossentropy car on a plusieurs classes)

# %%
def metric_age(y_true, y_pred):
    return tf.keras.metrics.MAE(y_true[:,0], y_pred[:,0]) * max_age

def metric_gender(y_true,y_pred):
    return tf.keras.metrics.binary_accuracy(y_true[:,1], y_pred[:,1])

def metric_ethnicity(y_true,y_pred):
    return tf.keras.metrics.sparse_categorical_accuracy(y_true[:,2], y_pred[:,2:])

# %% [markdown]
# On le compile, en choisissant bien la bonne fonction de perte (binary cross entropy pour une classif binaire) et les bonnes métriques

# %%
model.compile(loss=loss_function, optimizer='adam', metrics = [metric_age , metric_gender, metric_ethnicity]
            )

# %% [markdown]
# Et on entraîne

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                              epochs=10,  batch_size=32)
# Out:
# Train on 7794 samples, validate on 1949 samples
# Epoch 1/10
# 1280/7794 [===>..........................] - ETA: 2:39 - loss: 20.9147 - metric_age: 32.0250 - metric_gender: 0.4758 - metric_ethnicity: 0.2086
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-5b2d08c64f81> in <module>
#       1 history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
# ----> 2                               epochs=10,  batch_size=32)
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     778           validation_steps=validation_steps,
# ...

# %% [markdown]
# Bon manifestement là ça s'entraine pas, je pense qu'il faut plus de données. Je regarderai ça demain

# %%
y_pred = model.predict(X_test)

# %%
import matplotlib.pyplot as plt

ethnicity_mapping = {0:"White", 1:"Black", 2:"Asian", 3:"Indian", 4:"Hispanic"}
gender_mapping = {0:"Male", 1:"Female"}


def prediction(y_pred):
    return (y_pred[0]*max_age).round(), gender_mapping[y_pred[1].round()], ethnicity_mapping[np.argmax(y_pred[2:], axis=-1)]

fig, axs = plt.subplots(4, 5, figsize=(11, 7))

for row in range(4):
    for col in range(5):
        indice = np.random.randint(X_test.shape[0])
        pred = prediction(y_pred[indice])
        axs[row, col].imshow(X_test[indice])
        axs[row, col].axis('off')
        axs[row, col].set_title('{}, {}, {}'.format(pred[0], pred[1], pred[2]))
        
plt.show()
